# %%
from os import sys
import os
sys.path.append('../')

# Getting packages #
# %matplotlib widget

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

import plotly.express as px

# import main
import propellers
import motors
from aircraft import airplane
import cl_finders

# Setting Plot Defaults
plt.style.use('../basic_plotter.mplstyle')

# %%
path_1 = '../Results/2023-05-26_LinusSteadyLevel/'
path_5 = '../Results/2023-07-06_CREATeVCruising/'

# %%
ct_cruise_segresult_2023 = pd.read_pickle(path_5+'ct_cruise_segresult.pkl')
eta_cruise_segresult_2023 = pd.read_pickle(path_5+'eta_cruise_segresult.pkl')

linus_cruise_segresult_2023 = pd.read_pickle(path_1+'acceleration_binresult.pkl')

# %%
df = (ct_cruise_segresult_2023.fit_polar)
print(df)
# Out:
# [0.03008879 0.91431118 0.        ]

# %%
df = (ct_cruise_segresult_2023.ave_polar.CD)
df = ct_cruise_segresult_2023.vehicle.mass
print(ct_cruise_segresult_2023.vehicle.mass)
print(ct_cruise_segresult_2023.vehicle.area)
# Out:
# 12.502
# 2.4806000000000004

# %%
plt.figure(dpi=150)

# plt.plot(ct_cruise_binresult_june13.ave_polar.CD, ct_cruise_binresult_june13.ave_polar.CL, marker='s', markersize=2, color='green', linestyle='dashed', label="$C_T$ 2022 Pre-trip")
plt.plot(linus_cruise_segresult_2023.ave_polar.CD, linus_cruise_segresult_2023.ave_polar.CL, marker='d', markersize=2, color='green', linestyle='', label="$C_T$ 2023 CREATeV")
plt.legend()
plt.xlabel("$C_D$")
plt.ylabel("$C_L$")
plt.xlim([-0.05, 0.15])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
